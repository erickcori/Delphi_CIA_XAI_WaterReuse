# %% [markdown]
# <a href="https://colab.research.google.com/github/erickcori/Delphi_CIA_XAI_WaterReuse/blob/main/notebooks/visualizacion_SHAP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Subir la matriz CIM
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9378de0c-d17b-47fa-a62b-f1a8c2658bde" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9378de0c-d17b-47fa-a62b-f1a8c2658bde">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# 🔁 Versión Colab-compatible del código que me diste

# !pip install shap xgboost openpyxl --quiet

import pandas as pd
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from xgboost import XGBClassifier
import shap
import matplotlib.pyplot as plt
import os
from google.colab import files

# 📁 Subir el archivo manualmente
uploaded = files.upload()  # selecciona 'datos CIM.xlsx'

# 📂 Crear carpeta
os.makedirs("figures", exist_ok=True)

# ✅ Cambiar ruta: SIN carpeta "data/"
cim = pd.read_excel("datos CIM.xlsx", index_col=0).fillna(0)

# Normalizar
scaler = MinMaxScaler()
cim_normalized = pd.DataFrame(
    scaler.fit_transform(cim),
    index=cim.index,
    columns=cim.columns
)

# Variable objetivo
y = cim_normalized.idxmax(axis=1)
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Modelo
model = XGBClassifier(learning_rate=0.01, max_depth=3)
model.fit(cim_normalized, y_encoded)

# SHAP
explainer = shap.Explainer(model)
shap_values = explainer(cim_normalized)

# Graficar
shap.summary_plot(
    shap_values,
    cim_normalized,
    plot_type="bar",
    class_names=le.classes_,
    show=False
)

plt.gcf().set_size_inches(10, 6)
plt.title("Importancia de barreras por clase (SHAP)", fontsize=16)
plt.xlabel("Impacto medio (SHAP)", fontsize=12)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.tight_layout()

# Guardar
plt.savefig("figures/shap_summary_multiclase.png", dpi=300)
plt.close()

print("✅ Gráfico SHAP guardado en 'figures/shap_summary_multiclase.png'")
# Out:
#      <input type="file" id="files-d0356f97-e343-4de4-83ff-2e2212ef031d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d0356f97-e343-4de4-83ff-2e2212ef031d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Baja el grafico en la ubicacion que le digas
from google.colab import files
files.download("figures/shap_summary_multiclase.png")
